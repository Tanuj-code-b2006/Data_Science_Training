# %% [markdown]
# # Machine learning guide

# %% [raw]
# Step 1 - Import all  Libraries
# Step 2 -  Import dataset ueing pandas
# Step 3 - EDA or preprocessing our dataset
# Step 4 - Target variable select (x,y(x is input  , y is output data))
# Step 5 - Divide Data into two parts training and testing (x.y both)
# Step 6 - Import Model
# Step 7 - Fitting Trainig data in model (lr.fit(x_train,y_train))
# Step 8 - Make predictions (lr.predict(x_test))
# Step 9 - Check model evalution metrices(r2 score,mse,mae..)
# Step 10 - Convert model into pkl file then we will make gui and make prediction using frontend

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle

# %%
df = pd.read_csv("house_prices.csv")

# %%
df.head()
# Out:
#    HouseID     Location  Bedrooms  Bathrooms  SquareFeet   Price
# 0        1      Chicago         1          2        1928  469558
# 1        2      Chicago         2          1        1093  313063
# 2        3     New York         3          1        2100  571116
# 3        4      Chicago         4          2        2456  609514
# 4        5  Los Angeles         4          2        1524  475262

# %%
df.isnull().sum()
# Out:
# HouseID       0
# Location      0
# Bedrooms      0
# Bathrooms     0
# SquareFeet    0
# Price         0
# dtype: int64

# %%
df["Location"].unique()
# Out:
# array(['Chicago', 'New York', 'Los Angeles', 'Houston'], dtype=object)

# %%
df["Location"] = df["Location"].replace({
    "Chicago":"Noida",
    "New York":"Gurugram",
    "Los Angeles":"Mumbai",
    "Houston":"Delhi"})

# %%
df.head()
# Out:
#    HouseID  Location  Bedrooms  Bathrooms  SquareFeet   Price
# 0        1     Noida         1          2        1928  469558
# 1        2     Noida         2          1        1093  313063
# 2        3  Gurugram         3          1        2100  571116
# 3        4     Noida         4          2        2456  609514
# 4        5    Mumbai         4          2        1524  475262

# %%
x= df[["SquareFeet","Bedrooms","Bathrooms"]]
y= df["Price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9663664820775998

# %%
m=lr.coef_

# %%
c=lr.intercept_

# %%
m*4.0+c
# Out:
# array([ 97457.54426672, 145863.8404573 , 172114.97225032])

# %%
sns.scatterplot(x = 'SquareFeet',  y = 'Price' , data = df)

plt.plot(X_test , lr.predict(X_test) , color = 'red')

# %%
pickle.dump(lr, open("model.pkl", "wb"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 classifier = pickle.dump(lr, open("model.pkl", "wb"))
#
# NameError: name 'pickle' is not defined
