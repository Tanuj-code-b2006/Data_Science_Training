# %%
#filling :
1. Mode: categorical or ordinal data  -> Text 

2. Median:where outliers are too much

3. Mean: no outliers


#Can formatting be done in pandas -> heading extra bold,colored background,text highlight
#uploading and downloading
->sql
->json
->excel
->csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\bhard\Downloads\archive.zip")

# %%
df.head(20)
# Out:
#      User_ID  Product_ID        Category  Price (Rs.)  Discount (%)  \
# 0   337c166f  f414122f-e          Sports        36.53            15
# 1   d38a19bf  fde50f9c-5        Clothing       232.79            20
# 2   d7f5f0b0  0d96fc90-3          Sports       317.02            25
# 3   395d4994  964fc44b-d            Toys       173.19            25
# 4   a83c145c  d70e2fc6-e          Beauty       244.80            20
# 5   3fdcdae8  0816ee12-5           Books       241.86            50
# 6   12772337  d41e0b55-c            Toys        76.91             5
# 7   9f0194af  83b7dc04-5          Sports       213.23            20
# 8   7a8559d8  87c9c896-1          Sports       379.81             5
# 9   8911f0d1  31308875-b  Home & Kitchen       415.36            50
# 10  98857e41  b2b1af7b-7           Books        73.09            10
# 11  3b857e65  e221cf14-c          Beauty       393.77            15
# 12  204fab33  8c9a5f54-b  Home & Kitchen       287.69            10
# ...

# %%
df.tail()
# Out:
#        User_ID  Product_ID        Category  Price (Rs.)  Discount (%)  \
# 3655  67abda0a  28714133-6          Beauty       486.79             0
# 3656  34ebc1a0  08838c2c-9            Toys       212.87            15
# 3657  1defd3b1  c39a4f16-6  Home & Kitchen       389.76             0
# 3658  0611293d  b4f67f96-9     Electronics       447.66            30
# 3659  e73ad07c  a5d07442-d  Home & Kitchen       235.77            30
#
#       Final_Price(Rs.)    Payment_Method Purchase_Date
# 3655            486.79               UPI    14-05-2024
# 3656            180.94  Cash on Delivery    19-11-2024
# 3657            389.76       Net Banking    07-08-2024
# 3658            313.36               UPI    21-05-2024
# 3659            165.04               UPI    14-04-2024

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3660 entries, 0 to 3659
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           3660 non-null   object
#  1   Product_ID        3660 non-null   object
#  2   Category          3660 non-null   object
#  3   Price (Rs.)       3660 non-null   float64
#  4   Discount (%)      3660 non-null   int64
#  5   Final_Price(Rs.)  3660 non-null   float64
#  6   Payment_Method    3660 non-null   object
#  7   Purchase_Date     3660 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 228.9+ KB

# %%
df.describe()
# Out:
#        Price (Rs.)  Discount (%)  Final_Price(Rs.)
# count  3660.000000   3660.000000       3660.000000
# mean    254.800675     18.825137        206.906579
# std     141.682621     14.731338        122.687844
# min      10.090000      0.000000          5.890000
# 25%     134.012500      5.000000        104.512500
# 50%     253.845000     15.000000        199.185000
# 75%     377.595000     25.000000        304.117500
# max     499.960000     50.000000        496.820000

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Product_ID          0
# Category            0
# Price (Rs.)         0
# Discount (%)        0
# Final_Price(Rs.)    0
# Payment_Method      0
# Purchase_Date       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Category', 'Price (Rs.)', 'Discount (%)',
#        'Final_Price(Rs.)', 'Payment_Method', 'Purchase_Date'],
#       dtype='object')

# %%
df["User_ID"]
# Out:
# 0       337c166f
# 1       d38a19bf
# 2       d7f5f0b0
# 3       395d4994
# 4       a83c145c
#           ...
# 3655    67abda0a
# 3656    34ebc1a0
# 3657    1defd3b1
# 3658    0611293d
# 3659    e73ad07c
# Name: User_ID, Length: 3660, dtype: object

# %%
df["Price (Rs.)"]
# Out:
# 0        36.53
# 1       232.79
# 2       317.02
# 3       173.19
# 4       244.80
#          ...
# 3655    486.79
# 3656    212.87
# 3657    389.76
# 3658    447.66
# 3659    235.77
# Name: Price (Rs.), Length: 3660, dtype: float64

# %%
#Extracting records 
df[df["Price (Rs.)"]>200]
# Out:
#        User_ID  Product_ID        Category  Price (Rs.)  Discount (%)  \
# 1     d38a19bf  fde50f9c-5        Clothing       232.79            20
# 2     d7f5f0b0  0d96fc90-3          Sports       317.02            25
# 4     a83c145c  d70e2fc6-e          Beauty       244.80            20
# 5     3fdcdae8  0816ee12-5           Books       241.86            50
# 7     9f0194af  83b7dc04-5          Sports       213.23            20
# ...        ...         ...             ...          ...           ...
# 3655  67abda0a  28714133-6          Beauty       486.79             0
# 3656  34ebc1a0  08838c2c-9            Toys       212.87            15
# 3657  1defd3b1  c39a4f16-6  Home & Kitchen       389.76             0
# 3658  0611293d  b4f67f96-9     Electronics       447.66            30
# 3659  e73ad07c  a5d07442-d  Home & Kitchen       235.77            30
#
#       Final_Price(Rs.)    Payment_Method Purchase_Date
# 1               186.23       Net Banking    09-02-2024
# ...

# %%
df.drop_duplicates().reset_index(drop="TRUE")
# Out:
#        User_ID  Product_ID        Category  Price (Rs.)  Discount (%)  \
# 0     337c166f  f414122f-e          Sports        36.53            15
# 1     d38a19bf  fde50f9c-5        Clothing       232.79            20
# 2     d7f5f0b0  0d96fc90-3          Sports       317.02            25
# 3     395d4994  964fc44b-d            Toys       173.19            25
# 4     a83c145c  d70e2fc6-e          Beauty       244.80            20
# ...        ...         ...             ...          ...           ...
# 3655  67abda0a  28714133-6          Beauty       486.79             0
# 3656  34ebc1a0  08838c2c-9            Toys       212.87            15
# 3657  1defd3b1  c39a4f16-6  Home & Kitchen       389.76             0
# 3658  0611293d  b4f67f96-9     Electronics       447.66            30
# 3659  e73ad07c  a5d07442-d  Home & Kitchen       235.77            30
#
#       Final_Price(Rs.)    Payment_Method Purchase_Date
# 0                31.05       Net Banking    12-11-2024
# ...
